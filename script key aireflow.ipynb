# %%
from cryptography.fernet import Fernet
print(Fernet.generate_key().decode())
# Out:
# HTxb8IpXFQZnRDkwyR66gcVMCQu1t_O2jLy4S7oBP1Q=

# %%
# pour voir les composante de docker 
# dans terminal taper :
docker ps

# to remove container :  docker compose down -v
# to run container:  docker compose up -d
# pour creer images : 
docker build -t aifllow_ytb .

 docker system prune -a 

# Pour voir si les schémas et table ont été créés :

docker exec -it postgres psql -U yt_api_user -d elt_db
\dn
